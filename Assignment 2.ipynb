# %%
#Program to find the greatest of 3 numbers.
num1 = float(input())
num2 = float(input())
num3 = float(input())

if num1 == num2 and num2 == num3:
    print ("All the three numbers are equal!")

elif num1 == num2:
    if num1 > num3:
        print (f"{num1} is the greatest of the three numbers")
    else:
        print (f"{num3} is the greatest of the three numbers")

elif num1 == num3:
    if num1 > num2:
        print (f"{num1} is the greatest of the three numbers")
    else:
        print (f"{num2} is the greatest of the three numbers")

elif num2 == num3:
    if num2 > num1:
        print (f"{num2} is the greatest of the three numbers")
    else:
        print (f"{num1} is the greatest of the three numbers")

elif num1 > num2:
    if num1 > num3:
        print (f"{num1} is the greatest of the three numbers")
    else:
        print (f"{num3} is the greatest of the three numbers")

elif num2 > num1:
    if num2 > num3:
        print (f"{num2} is the greatest of the three numbers")
    else:
        print (f"{num3} is the greatest of the three numbers")
# Out:
# All the three numbers are equal!
