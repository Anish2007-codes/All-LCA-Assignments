# %%
#Assignment 1 - Create a dictionary, tuple and list of students and perform the following operations on the dictionary : Add, delete and update.

student_list = ["Anish", "Samey", "Soham", "Avaneesh", "Omkar"]
print (student_list)
student_tuple = ("Anish", "Samey", "Soham", "Omkar", "Avaneesh")
print (student_tuple)

student_dict = {
    101 : "Samey",
    102 : "Soham", 
    103 : "Anish",
    104 : "Avaneesh",
    105 : "Omkar"
}
print (f"The old dictionary was {student_dict}")
student_dict[106] = "Pranav"
student_dict[103] = "Advait"
del student_dict[101]
print (f"The new dictionary is {student_dict}")
# Out:
# ['Anish', 'Samey', 'Soham', 'Avaneesh', 'Omkar']
# ('Anish', 'Samey', 'Soham', 'Omkar', 'Avaneesh')
# The old dictionary was {101: 'Samey', 102: 'Soham', 103: 'Anish', 104: 'Avaneesh', 105: 'Omkar'}
# The new dictionary is {102: 'Soham', 103: 'Advait', 104: 'Avaneesh', 105: 'Omkar', 106: 'Pranav'}
